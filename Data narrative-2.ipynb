# %%
import pandas as pd

df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\usnews.data', header=None)

var1= df_aaup['State(postal code)'].nunique()
print("Number of different states having atleast one college:", var1)
var= df_aaup['FICE'].nunique()
print("Total number of colleges:", var+1)

# %%
import pandas as pd

df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\usnews.data', header=None)
var= df_aaup["Type"].unique()
print(var)
var1= df_aaup["Type"].value_counts()["I"]
print("Number of occurances of Type I are:", var1)
var2= df_aaup["Type"].value_counts()["IIA"]
print("Number of occurances of Type IIA are:", var2)
var3= df_aaup["Type"].value_counts()["VIIB"]
print("Number of occurances of Type VIIB are:", var3)
var4= df_aaup["Type"].value_counts()["IIB"]
print("Number of occurances of Type IIB are:", var4)
y= ["% number of Type I Universities", "% number of Type IIA Universities", "% number of Type IIB Universities"]
x=[df_aaup["Type"].value_counts()["I"],df_aaup["Type"].value_counts()["IIA"],df_aaup["Type"].value_counts()["IIB"]]
ex=[0.015,0.015,0.015]
plt.pie(x, autopct="%0.1f%%", colors=["#ebc713","#8aeb13","#eb5b13"], explode=ex)
x1=[50,30,20]
cr= plt.Circle(xy=(0,0),radius=0.3,facecolor="w")
plt.gca().add_artist(cr)

plt.legend(y, loc="best")
plt.tight_layout()
plt.show()
# Out:
# ['IIB' 'I' 'IIA' 'VIIB']
# Number of occurances of Type I are: 180
# Number of occurances of Type IIA are: 363
# Number of occurances of Type VIIB are: 1
# Number of occurances of Type IIB are: 617

# %%
import pandas as pd

df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\usnews.data', header=None)

var=df_aaup['State(postal code)'].value_counts().head(10)
var1=df_aaup['State(postal code)'].value_counts().mean()
print("Top 10 States with maximum number of colleges:")
print()
print(var)
print()
print("Mean number of colleges in a state(postal code):", var1)
# Out:
# Top 10 States with maximum number of colleges:
#
# PA    85
# NY    81
# TX    54
# CA    54
# OH    53
# IL    50
# NC    42
# MA    42
# IN    41
# VA    39
# Name: State(postal code), dtype: int64
#
# Mean number of colleges in a state(postal code): 22.326923076923077

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df_aaup1= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup1= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\usnews.data', header=None)
highest_avearge_salary = df_aaup.sort_values('Average salary- all ranks', ascending = False).head(10).set_index('college name')
plt.figure(figsize=(10,7))
sns.barplot(x = 'Average salary- all ranks', y= highest_avearge_salary.index , data = highest_avearge_salary, palette='YlOrBr')
plt.title("Top 10 Universities with highest average salary at all ranks", fontsize=16)
plt.xlabel("Yearly Salary(in $100's)", fontsize=14)
plt.ylabel("Name of the University", fontsize=14)
# Out:
# Text(0, 0.5, 'Name of the University')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\usnews.data', header=None)
var3=df_aaup[['college name','Average salary- full professors']].sort_values(by=['Average salary- full professors'], ascending=False).head(5)
print(var3)
# Out:
#                      college name Average salary- full professors
# 47      California Inst. of Tech.                             970
# 649          Princeton University                             963
# 77            Stanford University                             952
# 129               Yale University                             928
# 388  Massachusetts Inst. of Tech.                             903

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP1.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\usnews.data', header=None)
highest_salary_fprof = df_aaup.sort_values('Average salary- associate professors', ascending = False).head(10).set_index('college name')
plt.figure(figsize=(10,7))
sns.barplot(x = 'Average salary- associate professors', y= highest_salary_fprof.index , data = highest_salary_fprof, palette='Blues')
plt.title("Top 10 Universities with highest average salary of associate professors", fontsize=16)
plt.xlabel("Yearly Salary(in $100's)", fontsize=14)
plt.ylabel("Name of the University", fontsize=14)
# Out:
# Text(0, 0.5, 'Name of the University')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP1.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\usnews.data', header=None)
highest_salary_fprof = df_aaup.sort_values('Average salary- assistant professors', ascending = False).head(10).set_index('college name')
plt.figure(figsize=(10,7))
sns.barplot(x = 'Average salary- assistant professors', y= highest_salary_fprof.index , data = highest_salary_fprof, palette='icefire_r')
plt.title("Top 10 Universities with highest average salary of assistant professors", fontsize=16)
plt.xlabel("Yearly Salary(in $100's)", fontsize=14)
plt.ylabel("Name of the University", fontsize=14)
# Out:
# Text(0, 0.5, 'Name of the University')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\usnews.data', header=None)
var1=df_aaup[['college name','Average compensation- full professors']].sort_values(by=['Average compensation- full professors'], ascending=False).head(5)
print(var1)
# Out:
#                     college name Average compensation- full professors
# 845   Carnegie-Mellon University                                   994
# 1005             Rice University                                   992
# 406            Wellesley College                                   988
# 990        Vanderbilt University                                   988
# 306     University of Notre Dame                                   985

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\usnews.data', header=None)
highest_avearage_salary = df_aaup.sort_values('Average compensation- all ranks', ascending = False).head(10).set_index('college name')
plt.figure(figsize=(10,7))
sns.barplot(x = 'Average compensation- all ranks', y= highest_avearage_salary.index , data = highest_avearage_salary, palette='rocket')
plt.title("Top 10 Universities with highest average compensation at all ranks", fontsize=16)
plt.xlabel("Yearly Compensation(in $100's)", fontsize=14)
plt.ylabel("Name of the University", fontsize=14)
# Out:
# Text(0, 0.5, 'Name of the University')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\usnews.data', header=None)
highest_number_of_faculty = df_aaup.sort_values('Number of faculty- all ranks', ascending = False).head(10).set_index('college name')
plt.figure(figsize=(10,7))
sns.barplot(x = 'Number of faculty- all ranks', y= highest_number_of_faculty.index , data = highest_number_of_faculty, palette='crest')
plt.title("Top 10 Universities with highest number of faculty at all ranks", fontsize=16)
plt.xlabel("Number of faculty at all ranks", fontsize=14)
plt.ylabel("Name of the University", fontsize=14)
# Out:
# Text(0, 0.5, 'Name of the University')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\usnews.data', header=None)
var1=df_aaup[['college name','Number of faculty- all ranks']].sort_values(by=['Number of faculty- all ranks'], ascending=False).head(3)
print(var1)
y= ["% number of full prof", "% number of associate prof", "% number of assistant prof", "% number of instructors"]
x=[df_aaup.iloc[153,12],df_aaup.iloc[153,13],df_aaup.iloc[153,14],df_aaup.iloc[153,15]]
ex=[0.015,0.015,0.015,0.015]
plt.pie(x, autopct="%0.1f%%", explode=ex)
plt.legend(y, loc="best")
plt.title("University of Florida")
plt.tight_layout()
plt.show()
# Out:
#                     college name  Number of faculty- all ranks
# 153        University of Florida                          2261
# 1028    Univ. of Texas at Austin                          2099
# 480   Univ.of Michigan-Ann Arbor                          1968

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\usnews.data', header=None)
var1=df_aaup[['college name','Number of faculty- all ranks']].sort_values(by=['Number of faculty- all ranks'], ascending=False).head(3)
print(var1)
y= ["% number of full prof", "% number of associate prof", "% number of assistant prof", "% number of instructors"]
x=[df_aaup.iloc[1028,12],df_aaup.iloc[1028,13],df_aaup.iloc[1028,14],df_aaup.iloc[1028,15]]
ex=[0.015,0.015,0.015,0.015]
plt.pie(x, autopct="%0.1f%%", explode=ex, )
plt.legend(y, loc="best")
plt.title("Univ. of Texas")
plt.tight_layout()
plt.show()
# Out:
#                     college name  Number of faculty- all ranks
# 153        University of Florida                          2261
# 1028    Univ. of Texas at Austin                          2099
# 480   Univ.of Michigan-Ann Arbor                          1968

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\usnews.data', header=None)
var1=df_aaup[['college name','Number of faculty- all ranks']].sort_values(by=['Number of faculty- all ranks'], ascending=False).head(5)
print(var1)
y= ["% number of full prof", "% number of associate prof", "% number of assistant prof", "% number of instructors"]
x=[df_aaup.iloc[480,12],df_aaup.iloc[480,13],df_aaup.iloc[480,14],df_aaup.iloc[480,15]]
ex=[0.015,0.015,0.015,0.015]
plt.pie(x, autopct="%0.1f%%", explode=ex)
plt.legend(y, loc="best")
plt.title("Univ. of Michigan-Ann Arbor")
plt.tight_layout()
plt.show()
# Out:
#                       college name  Number of faculty- all ranks
# 153          University of Florida                          2261
# 1028      Univ. of Texas at Austin                          2099
# 480     Univ.of Michigan-Ann Arbor                          1968
# 798   Ohio State Univ.-Main campus                          1910
# 1110      University of Washington                          1906

# %%
import pandas as pd

df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\usnews.data', header=None)

var= df_usnews[0].nunique()
print("Total number of colleges:", var)
var1= df_usnews[2].nunique()
print("Number of different states containing atleast one college is:", var1)
# Out:
# Total number of colleges: 1302
# Number of different states containing atleast one college is: 51

# %%
import pandas as pd

df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\usnews.data', header=None)

var=df_usnews[2].value_counts().head(5)
print("Top 5 States with highest number of Universities:")
print()
print(var)
# Out:
# Top 5 States with highest number of Universities:
#
# NY    101
# PA     83
# CA     70
# TX     60
# MA     56
# Name: 2, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\usnews.data', header=None)

var= df_usnews[3].nunique()
print("Total number of types of college present are:", var)
var1= df_usnews[3].value_counts()[1]
print("Number of public schools among the total is:", var1)
var2= df_usnews[3].value_counts()[2]
print("Number of private schools among the total is:", var2)
y= ["% number of Public colleges", "% number of Private colleges"]
x=[df_usnews[3].value_counts()[1],df_usnews[3].value_counts()[2]]
ex=[0.015,0.015]
plt.pie(x, autopct="%0.1f%%", colors=["#eb5b13","#8aeb13"], explode=ex)
x1=[50,50]
cr= plt.Circle(xy=(0,0),radius=0.3,facecolor="w")
plt.gca().add_artist(cr)
plt.legend(y, loc="best")
plt.title("Public v/s Private")
plt.tight_layout()
plt.show()
# Out:
# Total number of types of college present are: 2
# Number of public schools among the total is: 470
# Number of private schools among the total is: 832

# %%
## highest application number vs grad. rate
## 103 has lowest new student enrolled and highset phd and terminal faculty then also its grad. rate is lesser depicts that
## education depends on its quality but not quantity
## highest grad. rate is of 785
## higher number of applications is more in private colleges than in public.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\USNEWS1.csv', header=None)

var1=df_usnews[[1,3,14,16,29,34]].sort_values(by=[14], ascending=False).head(10)
print(var1)
width=0
x= [df_usnews.iloc[750,1],df_usnews.iloc[101,1],df_usnews.iloc[352,1],df_usnews.iloc[440,1],df_usnews.iloc[98,1],df_usnews.iloc[103,1],df_usnews.iloc[1038,1],df_usnews.iloc[785,1],df_usnews.iloc[559,1],df_usnews.iloc[542,1]]
y1=[df_usnews.iloc[750,14],df_usnews.iloc[101,14],df_usnews.iloc[352,14],df_usnews.iloc[440,14],df_usnews.iloc[98,14],df_usnews.iloc[103,14],df_usnews.iloc[1038,14],df_usnews.iloc[785,14],df_usnews.iloc[559,14],df_usnews.iloc[542,14]]
y2=[df_usnews.iloc[750,15],df_usnews.iloc[101,15],df_usnews.iloc[352,15],df_usnews.iloc[440,15],df_usnews.iloc[98,15],df_usnews.iloc[103,15],df_usnews.iloc[1038,15],df_usnews.iloc[785,15],df_usnews.iloc[559,15],df_usnews.iloc[542,15]]
y3=[df_usnews.iloc[750,16],df_usnews.iloc[101,16],df_usnews.iloc[352,16],df_usnews.iloc[440,16],df_usnews.iloc[98,16],df_usnews.iloc[103,16],df_usnews.iloc[1038,16],df_usnews.iloc[785,16],df_usnews.iloc[559,16],df_usnews.iloc[542,16]]
p= np.arange(len(x))
p1=[j+width for j in p]
p2=[j+width for j in p]
plt.bar(p,y1,color="#ebc713",label="Number of applications received")
plt.bar(p1,y2,color="#eb5b13",label="Number of applications accepted")
plt.bar(p2,y3,color="#8aeb13",label="Number of new students enrolled")
plt.title("")
plt.xticks(p+width/2,x,rotation=85)
plt.legend()
plt.show()
# Out:
#                                            1   3      14    16   29  34
# 750                  Rutgers at New Brunswick   1  48094  4520   90  77
# 101   University of California at Los Angeles   1  22165  3591   97  77
# 352       Purdue University at West Lafayette   1  21804  5874   86  67
# 440                         Boston University   2  20192  3810   80  72
# 98       University of California at Berkeley   1  19873  3215   93  78
# 103     University of California at San Diego   1  19433  2481  100  66
# 1038     Pennsylvania State Univ. Main Campus   1  19315  3450   77  63
# 785                        Cornell University   2  19227  3286   91  93
# 559       University of Michigan at Ann Arbor   1  19152  4893   90  87
# 542                 Michigan State University   1  18114  6180   93  71

# %%
## highest graduation rate

import pandas as pd

df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\USNEWS1.csv', header=None)

var1=df_usnews[[1,3,16,29,30,31,34]].sort_values(by=[34], ascending=False).head(10)
print(var1)
# Out:
#                                    1   3    16   29   30    31   34
# 771                 Cazenovia College   2  527   22   47  14.3  118
# 596   Missouri Southern State College   1  913   52   54  20.3  100
# 594                Lindenwood College   2  356   65   85  24.1  100
# 1241                 Heritage College   2   21   48   52   9.5  100
# 77                Harvey Mudd College   2  178  100  100   8.2  100
# 1228                  Goddard College   2   49   56   72  14.5  100
# 824                     Siena College   2  628   71   82  14.1  100
# 1210           University of Richmond   2  756   75   89  11.7  100
# 979                Grove City College   2  573   65   65  18.4  100
# 108            Santa Clara University   2  888   88   92  13.9  100

# %%
## highest number of PHD faculty
import pandas as pd

df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\USNEWS1.csv', header=None)

var1=df_usnews[[1,3,14,15,29,31,34]].sort_values(by=[29], ascending=False).head(5)
print(var1)
# Out:
#                                      1   3     14   15   29    31   34
# 821                       Sage Colleges   2   419  170  105   8.2   64
# 1175  Texas A&M University at Galveston   1   529  481  103  17.4   43
# 77                  Harvey Mudd College   2  1377  572  100   8.2  100
# 114               University of Judaism   2    52   36  100   7.2   55
# 78                       Pitzer College   2  1133  630  100  10.4   73

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\USNEWS1.csv', header=None)
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\USNEWS1.csv', names= ['F', 'cl. name', 'state', 'ind', 'avg ms score', 'avg vs score', 'avg cs score', 'avg act score', 'fqm', 'tqm', 'fqv', 'tqv', 'fq act', 'tq act', 'nu recieved', 'nu accepted', 'new nu enrolled', 'top 10 hs', 'top 25 hs', 'nu full', 'nu part', 'in tuition', 'out tuition', 'rb cost', 'r cost', 'b cost', 'additional fees', 'book cost', 'personal cost', 'phd faculty', 'terminal faculty', 's/f ratio', '%alumini donate', 'ins expenditure per student', 'grad. rate'])
highest_hsgrade_stud = df_usnews.sort_values("top 10 hs", ascending = False).head(10).set_index("cl. name")
plt.figure(figsize=(10,7))
sns.barplot(x = "top 10 hs", y= highest_hsgrade_stud.index , data = highest_hsgrade_stud, palette='rocket_r')
plt.title("Top 10 Colleges with highest % of new students from top 10% of H.S. class", fontsize=16)
plt.xlabel("Number of new students from top 10% of H.S. class", fontsize=14)
plt.ylabel("Name of the University", fontsize=14)
# Out:
# Text(0, 0.5, 'Name of the University')

# %%
## additional fees vs %alumini donation
##      (sorted by both ascepts)
import pandas as pd

df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\USNEWS1.csv', header=None)

var1=df_usnews[[1,26,32]].sort_values(by=[32], ascending=False).head(5)
print(var1)
print()
var2= df_usnews[[1,26,32]].sort_values(by=[26], ascending=False).head(5)
print(var2)
# Out:
#                                     1    26  32
# 726  Thomas More Coll. of Liberal Arts    0  81
# 482                   Williams College  141  64
# 432                    Amherst College  272  63
# 562                   Carleton College  126  60
# 790                   Hamilton College    0  60
#
#                                             1     26  32
# 99           University of California at Davis  4374  11
# 104  University of California at Santa Barbara  4372   6
# 103      University of California at San Diego  4128   6
# 105     University of California at Santa Cruz  4110  10
# 102      University of California at Riverside  4092   8

# %%
## sat and act scores vs highest new students from top 10% of H.S. class 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\USNEWS1.csv', header=None)
width=0
var=df_usnews[[1,6,7,17]].sort_values(by=[17], ascending=False).head(10)
print(var)
x= [df_usnews.iloc[455,1],df_usnews.iloc[103,1],df_usnews.iloc[99,1]]
y1=[df_usnews.iloc[455,6],df_usnews.iloc[103,6],df_usnews.iloc[99,6]]
y2=[df_usnews.iloc[455,7],df_usnews.iloc[103,7],df_usnews.iloc[99,7]]
p= np.arange(len(x))
p1=[j+width for j in p]
plt.bar(p,y1,color="#ebc713",label="Avg SAT score")
plt.bar(p1,y2,color="#eb5b13",label="Avg ACT score")
plt.title("")
plt.xticks(p+width/2,x,rotation=25)
plt.legend()
plt.show()
# Out:
#                                           1     6   7   17
# 54        California Institute of Technology  1410   0  98
# 455    Massachusetts Institute of Technology  1381  31  96
# 98      University of California at Berkeley  1218   0  95
# 77                       Harvey Mudd College  1370   0  95
# 103    University of California at San Diego  1131  26  95
# 154                          Yale University     0   0  95
# 99         University of California at Davis  1070  24  95
# 105   University of California at Santa Cruz  1059   0  94
# 101  University of California at Los Angeles  1141   0  93
# 451                       Harvard University     0   0  90

# %%
## all fees and expenditures vs highest grad. colleges
import pandas as pd

df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\USNEWS1.csv', header=None)

var1=df_usnews[[1,24,25,26,27,28,34]].sort_values(by=[34], ascending=False).head(5)
print(var1)
y= ["Room costs", "Board costs", "Additonal fees", "Book costs","Personal spending"]
x=[df_usnews.iloc[771,24],df_usnews.iloc[771,25],df_usnews.iloc[771,26],df_usnews.iloc[771,27],df_usnews.iloc[771,28]]
ex=[0.015,0.015,0.015,0.015,0.015]
plt.pie(x, autopct="%0.1f%%", explode=ex)
plt.legend(y, loc="best")
plt.title("Cazenovia College")
plt.tight_layout()
plt.show()
# Out:
#                                    1     24    25   26    27    28   34
# 771                 Cazenovia College  2420  2420  395   600   500  118
# 596   Missouri Southern State College     0     0   86   200   400  100
# 594                Lindenwood College  2400  2400  200  1000  4200  100
# 1241                 Heritage College     0     0   20   672  2424  100
# 77                Harvey Mudd College  3320  3370  465   700   900  100

# %%
import pandas as pd

df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\USNEWS1.csv', header=None)

var1=df_usnews[[1,24,25,26,27,28,34]].sort_values(by=[34], ascending=False).head(5)
print(var1)
y= ["Room costs", "Board costs", "Additonal fees", "Book costs","Personal spending"]
x=[df_usnews.iloc[594,24],df_usnews.iloc[594,25],df_usnews.iloc[594,26],df_usnews.iloc[594,27],df_usnews.iloc[594,28]]
ex=[0.015,0.015,0.015,0.015,0.015]
plt.pie(x, autopct="%0.1f%%", explode=ex)
plt.legend(y, loc="best")
plt.title("Lindenwood College")
plt.tight_layout()
plt.show()
# Out:
#                                    1     24    25   26    27    28   34
# 771                 Cazenovia College  2420  2420  395   600   500  118
# 596   Missouri Southern State College     0     0   86   200   400  100
# 594                Lindenwood College  2400  2400  200  1000  4200  100
# 1241                 Heritage College     0     0   20   672  2424  100
# 77                Harvey Mudd College  3320  3370  465   700   900  100

# %%
import pandas as pd

df_aaup= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\Data narrative assign-2\\aaup.data', header=None)
df_aaup= pd.read_csv("C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\AAUP.csv", names= ['FICE', 'college name', 'State(postal code)', 'Type', 'Average salary- full professors', 'Average salary- associate professors', 'Average salary- assistant professors', 'Average salary- all ranks', 'Average compensation- full professors', 'Average compensation- associate professors', 'Average compensation- assistant professors', 'Average compensation- all ranks', 'Number of full professors', 'Number of associate professors', 'Number of assistant professors', 'Number of instructors', 'Number of faculty- all ranks'])
df_usnews= pd.read_csv('C:\\Users\\vatsal trivedi\\Documents\\data narr-2\\USNEWS1.csv', header=None)

var1=df_usnews[[1,24,25,26,27,28,34]].sort_values(by=[34], ascending=False).head(5)
print(var1)
y= ["Room costs", "Board costs", "Additonal fees", "Book costs","Personal spending"]
x=[df_usnews.iloc[77,24],df_usnews.iloc[77,25],df_usnews.iloc[77,26],df_usnews.iloc[77,27],df_usnews.iloc[77,28]]
ex=[0.015,0.015,0.015,0.015,0.015]
plt.pie(x, autopct="%0.1f%%", explode=ex)
plt.legend(y, loc="best")
plt.title("Harvey Mudd College")
plt.tight_layout()
plt.show()
# Out:
#                                    1     24    25   26    27    28   34
# 771                 Cazenovia College  2420  2420  395   600   500  118
# 596   Missouri Southern State College     0     0   86   200   400  100
# 594                Lindenwood College  2400  2400  200  1000  4200  100
# 1241                 Heritage College     0     0   20   672  2424  100
# 77                Harvey Mudd College  3320  3370  465   700   900  100
